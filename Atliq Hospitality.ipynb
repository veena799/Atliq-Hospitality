# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("E:\\unified mentor projects\\atliq hospitatity\dim_date.csv")

# %%
df
# Out:
#          date  mmm yy week no  day_type
# 0   01-May-22  May 22    W 19   weekend
# 1   02-May-22  May 22    W 19  weekeday
# 2   03-May-22  May 22    W 19  weekeday
# 3   04-May-22  May 22    W 19  weekeday
# 4   05-May-22  May 22    W 19  weekeday
# ..        ...     ...     ...       ...
# 87  27-Jul-22  Jul 22    W 31  weekeday
# 88  28-Jul-22  Jul 22    W 31  weekeday
# 89  29-Jul-22  Jul 22    W 31  weekeday
# 90  30-Jul-22  Jul 22    W 31   weekend
# 91  31-Jul-22  Jul 22    W 32   weekend
#
# [92 rows x 4 columns]

# %%
df1= pd.read_csv("E:\\unified mentor projects\\atliq hospitatity\dim_hotels.csv")

# %%
df1
# Out:
#     property_id  property_name  category       city
# 0         16558   Atliq Grands    Luxury      Delhi
# 1         16559  Atliq Exotica    Luxury     Mumbai
# 2         16560     Atliq City  Business      Delhi
# 3         16561      Atliq Blu    Luxury      Delhi
# 4         16562      Atliq Bay    Luxury      Delhi
# 5         16563   Atliq Palace  Business      Delhi
# 6         17558   Atliq Grands    Luxury     Mumbai
# 7         17559  Atliq Exotica    Luxury     Mumbai
# 8         17560     Atliq City  Business     Mumbai
# 9         17561      Atliq Blu    Luxury     Mumbai
# 10        17562      Atliq Bay    Luxury     Mumbai
# 11        17563   Atliq Palace  Business     Mumbai
# 12        18558   Atliq Grands    Luxury  Hyderabad
# 13        18559  Atliq Exotica    Luxury  Hyderabad
# 14        18560     Atliq City  Business  Hyderabad
# 15        18561      Atliq Blu    Luxury  Hyderabad
# 16        18562      Atliq Bay    Luxury  Hyderabad
# ...

# %%
df2= pd.read_csv("E:\\unified mentor projects\\atliq hospitatity\dim_rooms.csv")

# %%
df2
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df3= pd.read_csv("E:\\unified mentor projects\\atliq hospitatity\\fact_aggregated_bookings.csv")

# %%
df3
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 0           16559     01-May-22           RT1                   25        30
# 1           19562     01-May-22           RT1                   28        30
# 2           19563     01-May-22           RT1                   23        30
# 3           17558     01-May-22           RT1                   13        19
# 4           16558     01-May-22           RT1                   18        19
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13        18
# 9196        16559     31-Jul-22           RT4                   13        18
# 9197        17558     31-Jul-22           RT4                    3         6
# 9198        19563     31-Jul-22           RT4                    3         6
# 9199        17561     31-Jul-22           RT4                    3         4
#
# [9200 rows x 5 columns]

# %%
df4= pd.read_csv("E:\\unified mentor projects\\atliq hospitatity\\fact_bookings.csv")

# %%
df4
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558   2022-04-27    2022-05-01
# 1        May012216558RT12        16558   2022-04-30    2022-05-01
# 2        May012216558RT13        16558   2022-04-28    2022-05-01
# 3        May012216558RT14        16558   2022-04-28    2022-05-01
# 4        May012216558RT15        16558   2022-04-27    2022-05-01
# ...                   ...          ...          ...           ...
# 134585   Jul312217564RT46        17564   2022-07-29    2022-07-31
# 134586   Jul312217564RT47        17564   2022-07-30    2022-07-31
# 134587   Jul312217564RT48        17564   2022-07-30    2022-07-31
# 134588   Jul312217564RT49        17564   2022-07-29    2022-07-31
# 134589  Jul312217564RT410        17564   2022-07-31    2022-07-31
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0         2022-05-02          3           RT1    direct online            1.0
# ...

# %%
data_path = "E:\\unified mentor projects\\atliq hospitatity\\metrics_list.xlsx"

# %%
df5 = pd.read_excel(data_path)

# %%
df5
# Out:
#   Unnamed: 0                Unnamed: 1  \
# 0        Sno                  Measuers
# 1          1                   Revenue
# 2          2            Total Bookings
# 3          3            Average Rating
# 4          4            Total Capacity
# 5          5  Total Succesful bookings
# 6          6               Occupancy %
# 7          7  Total Cancelled Bookings
# 8          8         Cancellation Rate
#
#                                           Unnamed: 2
# 0                                        Description
# 1                            Sum of revenue_realized
# 2               Count of booking_id in fact_bookings
# 3                           Average of ratings_given
# 4                                    Sum of capacity
# 5      Sum of successful_bookings from fact_bookings
# 6  Ratio of Total Successful Bookings to Total Ca...
# 7  Count of booking_id in which booking_status = ...
# 8  Ratio of 'Total Cancelled Bookings' to 'Total ...

# %%
df.isnull().sum()
# Out:
# date        0
# mmm yy      0
# week no     0
# day_type    0
# dtype: int64

# %%
df1.isnull().sum()
# Out:
# property_id      0
# property_name    0
# category         0
# city             0
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# room_id       0
# room_class    0
# dtype: int64

# %%
df3.isnull().sum()
# Out:
# property_id            0
# check_in_date          0
# room_category          0
# successful_bookings    0
# capacity               0
# dtype: int64

# %%
df4.isnull().sum()
# Out:
# booking_id               0
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                0
# room_category            0
# booking_platform         0
# ratings_given        77907
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# dtype: int64

# %%
df5.isnull().sum()
# Out:
# Unnamed: 0    0
# Unnamed: 1    0
# Unnamed: 2    0
# dtype: int64

# %%
df1.shape
# Out:
# (25, 4)

# %%
df4.shape
# Out:
# (134590, 12)

# %%
dfa = df4.dropna()

# %%
dfa
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558   2022-04-27    2022-05-01
# 2        May012216558RT13        16558   2022-04-28    2022-05-01
# 4        May012216558RT15        16558   2022-04-27    2022-05-01
# 5        May012216558RT16        16558   2022-05-01    2022-05-01
# 9       May012216558RT110        16558   2022-04-28    2022-05-01
# ...                   ...          ...          ...           ...
# 134582   Jul312217564RT43        17564   2022-07-31    2022-07-31
# 134584   Jul312217564RT45        17564   2022-07-30    2022-07-31
# 134585   Jul312217564RT46        17564   2022-07-29    2022-07-31
# 134586   Jul312217564RT47        17564   2022-07-30    2022-07-31
# 134588   Jul312217564RT49        17564   2022-07-29    2022-07-31
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0         2022-05-02          3           RT1    direct online            1.0
# ...

# %%
dfa.isnull().sum()
# Out:
# booking_id           0
# property_id          0
# booking_date         0
# check_in_date        0
# checkout_date        0
# no_guests            0
# room_category        0
# booking_platform     0
# ratings_given        0
# booking_status       0
# revenue_generated    0
# revenue_realized     0
# dtype: int64

# %%
dfa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56683 entries, 0 to 134588
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   booking_id         56683 non-null  object
#  1   property_id        56683 non-null  int64
#  2   booking_date       56683 non-null  object
#  3   check_in_date      56683 non-null  object
#  4   checkout_date      56683 non-null  object
#  5   no_guests          56683 non-null  int64
#  6   room_category      56683 non-null  object
#  7   booking_platform   56683 non-null  object
#  8   ratings_given      56683 non-null  float64
#  9   booking_status     56683 non-null  object
#  10  revenue_generated  56683 non-null  int64
#  11  revenue_realized   56683 non-null  int64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 5.6+ MB

# %%
dfa.head(15)
# Out:
#            booking_id  property_id booking_date check_in_date checkout_date  \
# 0    May012216558RT11        16558   2022-04-27    2022-05-01    2022-05-02
# 2    May012216558RT13        16558   2022-04-28    2022-05-01    2022-05-04
# 4    May012216558RT15        16558   2022-04-27    2022-05-01    2022-05-02
# 5    May012216558RT16        16558   2022-05-01    2022-05-01    2022-05-03
# 9   May012216558RT110        16558   2022-04-28    2022-05-01    2022-05-02
# 10  May012216558RT111        16558   2022-04-29    2022-05-01    2022-05-07
# 11  May012216558RT112        16558   2022-04-26    2022-05-01    2022-05-02
# 12  May012216558RT113        16558   2022-04-26    2022-05-01    2022-05-07
# 19   May012216558RT22        16558   2022-04-30    2022-05-01    2022-05-03
# 23   May012216558RT26        16558   2022-04-27    2022-05-01    2022-05-02
# 27  May012216558RT210        16558   2022-04-27    2022-05-01    2022-05-02
# ...

# %%
d = pd.DataFrame(dfa)
d
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558   2022-04-27    2022-05-01
# 2        May012216558RT13        16558   2022-04-28    2022-05-01
# 4        May012216558RT15        16558   2022-04-27    2022-05-01
# 5        May012216558RT16        16558   2022-05-01    2022-05-01
# 9       May012216558RT110        16558   2022-04-28    2022-05-01
# ...                   ...          ...          ...           ...
# 134582   Jul312217564RT43        17564   2022-07-31    2022-07-31
# 134584   Jul312217564RT45        17564   2022-07-30    2022-07-31
# 134585   Jul312217564RT46        17564   2022-07-29    2022-07-31
# 134586   Jul312217564RT47        17564   2022-07-30    2022-07-31
# 134588   Jul312217564RT49        17564   2022-07-29    2022-07-31
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0         2022-05-02          3           RT1    direct online            1.0
# ...

# %%
result = pd.merge(df1, d, on='property_id', how='inner')

# %%
result['room_category'] = result['room_category'].str.replace('RT1','Standard')
result['room_category'] = result['room_category'].str.replace('RT2','Elite')
result['room_category'] = result['room_category'].str.replace('RT3','Premium')
result['room_category'] = result['room_category'].str.replace('RT4','Presidential')
result
# Out:
#        property_id  property_name  category    city         booking_id  \
# 0            16558   Atliq Grands    Luxury   Delhi   May012216558RT11
# 1            16558   Atliq Grands    Luxury   Delhi   May012216558RT13
# 2            16558   Atliq Grands    Luxury   Delhi   May012216558RT15
# 3            16558   Atliq Grands    Luxury   Delhi   May012216558RT16
# 4            16558   Atliq Grands    Luxury   Delhi  May012216558RT110
# ...            ...            ...       ...     ...                ...
# 56678        17564  Atliq Seasons  Business  Mumbai   Jul312217564RT43
# 56679        17564  Atliq Seasons  Business  Mumbai   Jul312217564RT45
# 56680        17564  Atliq Seasons  Business  Mumbai   Jul312217564RT46
# 56681        17564  Atliq Seasons  Business  Mumbai   Jul312217564RT47
# 56682        17564  Atliq Seasons  Business  Mumbai   Jul312217564RT49
#
#       booking_date check_in_date checkout_date  no_guests room_category  \
# ...

# %% [markdown]
# # DATA VISUALIZATION

# %%
import seaborn as sns
plt.subplots(figsize=(20,12))
sns.heatmap(result.corr(),annot=True)
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_9424\4061814485.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(result.corr(),annot=True)

# %%
plt.figure(figsize = (20,12))
sns.barplot(data=result,x='property_name',y='ratings_given')
# Out:
# <Axes: xlabel='property_name', ylabel='ratings_given'>

# %%
result.head()
# Out:
#    property_id property_name category   city         booking_id booking_date  \
# 0        16558  Atliq Grands   Luxury  Delhi   May012216558RT11   2022-04-27
# 1        16558  Atliq Grands   Luxury  Delhi   May012216558RT13   2022-04-28
# 2        16558  Atliq Grands   Luxury  Delhi   May012216558RT15   2022-04-27
# 3        16558  Atliq Grands   Luxury  Delhi   May012216558RT16   2022-05-01
# 4        16558  Atliq Grands   Luxury  Delhi  May012216558RT110   2022-04-28
#
#   check_in_date checkout_date  no_guests room_category booking_platform  \
# 0    2022-05-01    2022-05-02          3      Standard    direct online
# 1    2022-05-01    2022-05-04          2      Standard          logtrip
# 2    2022-05-01    2022-05-02          4      Standard    direct online
# 3    2022-05-01    2022-05-03          2      Standard           others
# 4    2022-05-01    2022-05-02          1      Standard           others
#
#    ratings_given booking_status  revenue_generated  revenue_realized
# ...

# %%
plt.figure(figsize = (20,12))
sns.barplot(data=result,x='property_name',y='revenue_generated')
# Out:
# <Axes: xlabel='property_name', ylabel='revenue_generated'>

# %%
plt.figure(figsize = (20,12))
sns.histplot(data=result,x='room_category',y='ratings_given')
# Out:
# <Axes: xlabel='room_category', ylabel='ratings_given'>

# %%
#result.drop['property_id','revenue_realized']

# %%
plt.figure(figsize= (20,12))
sns.barplot(data=result,x='booking_date',y='revenue_generated',width=0.9)
# Out:
# <Axes: xlabel='booking_date', ylabel='revenue_generated'>

# %%
#sns.barplot(result['room_category'])
sns.countplot(x="room_category", data=result)
plt.title("Frequency of Categories")
plt.show()

# %%
sns.violinplot(x="category", y="no_guests", data=result)
plt.title("Distribution of Categories")
plt.show()

# %%
sns.countplot(x="city", data=result,color= 'k')
plt.title("Frequency of Categories")
plt.show()

# %%
from wordcloud import WordCloud

wordcloud = WordCloud(width=800, height=400).generate(' '.join(result['property_name']))
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
result['property_name'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title("Proportion of Categories")
plt.show()

# %%
result['category'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: ylabel='category'>

# %%
result['date'] = result['booking_date'].str.replace('booking_date','date')
#replace('booking_date','date')

# %%
plt.figure(figsize=(20,12))
sns.lineplot(x='booking_date', y='city', data=result, marker='o')
# Out:
# <Axes: xlabel='booking_date', ylabel='city'>

# %%
result
# Out:
#        property_id  property_name  category    city         booking_id  \
# 0            16558   Atliq Grands    Luxury   Delhi   May012216558RT11
# 1            16558   Atliq Grands    Luxury   Delhi   May012216558RT13
# 2            16558   Atliq Grands    Luxury   Delhi   May012216558RT15
# 3            16558   Atliq Grands    Luxury   Delhi   May012216558RT16
# 4            16558   Atliq Grands    Luxury   Delhi  May012216558RT110
# ...            ...            ...       ...     ...                ...
# 56678        17564  Atliq Seasons  Business  Mumbai   Jul312217564RT43
# 56679        17564  Atliq Seasons  Business  Mumbai   Jul312217564RT45
# 56680        17564  Atliq Seasons  Business  Mumbai   Jul312217564RT46
# 56681        17564  Atliq Seasons  Business  Mumbai   Jul312217564RT47
# 56682        17564  Atliq Seasons  Business  Mumbai   Jul312217564RT49
#
#       booking_date check_in_date checkout_date  no_guests room_category  \
# ...

# %%
result['booking_platform'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: ylabel='booking_platform'>

# %%
sns.lineplot(x='category', y='booking_date', data=result, marker='o')
# Out:
# <Axes: xlabel='category', ylabel='booking_date'>
